# %% [markdown]
# # 03C - Matrizes
#
# Este notebook foi criado para apoiar o estudo da seção correspondente.
#
# ## Objetivos
# - revisar a teoria principal;
# - implementar exemplos em Python;
# - visualizar estruturas matemáticas;
#
# ## Bibliotecas úteis
# - numpy
# - sympy
# - matplotlib
# - networkx

# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt
import networkx as nx

print('Notebook inicializado: 03C - Matrizes')
